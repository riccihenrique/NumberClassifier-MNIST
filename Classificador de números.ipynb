# %%
import tensorflow as tf
import numpy as np

# %%
(X_train, y_train), (x_test, Y_test) = tf.keras.datasets.mnist.load_data(path="mnist.npz")

# %%
X_train = X_train / 255
X_train = X_train.reshape(-1, 28*28)

# %%
x_test = x_test / 255
x_test = x_test.reshape(-1, 28 * 28)

# %%
y_train.size
# Out:
# 60000

# %%
model = tf.keras.models.Sequential()

# %%
model.add(tf.keras.layers.Dense(units=512, activation='relu', input_shape=X_train[0].shape))
model.add(tf.keras.layers.Dense(256, activation='sigmoid'))
model.add(tf.keras.layers.Dense(10, activation='softmax'))

# %%
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['sparse_categorical_accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense (Dense)                (None, 512)               401920
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               131328
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                2570
# ...
# Total params: 535,818
# Trainable params: 535,818
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(X_train, y_train, epochs=50)
# Out:
# Epoch 1/50
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.2085 - sparse_categorical_accuracy: 0.9381
# Epoch 2/50
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0769 - sparse_categorical_accuracy: 0.9755
# Epoch 3/50
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0510 - sparse_categorical_accuracy: 0.9832
# Epoch 4/50
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0358 - sparse_categorical_accuracy: 0.9889
# Epoch 5/50
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0266 - sparse_categorical_accuracy: 0.9912
# Epoch 6/50
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0220 - sparse_categorical_accuracy: 0.9926
# Epoch 7/50
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0188 - sparse_categorical_accuracy: 0.9937
# Epoch 8/50
# ...

# %%
model.evaluate(x_test, Y_test)
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.1010 - sparse_categorical_accuracy: 0.9845
# [0.10104981809854507, 0.984499990940094]

# %%
import cv2
from google.colab.patches import cv2_imshow

# %%
image = cv2.imread('teste.png')
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
gray.shape

gray = 255 - gray
gray = gray / 255
gray = gray.reshape(-1, 28*28)

# %%
print(model.predict_classes(gray)[0])
# Out:
# 6

# %%
model.save('number_classifier_mnist.data')
# Out:
# INFO:tensorflow:Assets written to: number_classifier_mnist.data/assets
